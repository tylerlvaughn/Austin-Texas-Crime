# %%
#Dependencies
import requests
import json
import pandas as pd

#Google developer API Key
from config import gkey

# %%
# Bars
# Geo coordinates
target_coordinates = "30.266666, -97.733330"
target_search = "Bars"
target_radius = 8000
target_type = "bars"

# set up parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response = requests.get(base_url, params=params)

# %%
    # print the response url
    # print(response.url)

# %%
# convert response to json
places_data = response.json()

# Print pretty
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwI3feDRLpElXN5ZgaDiow67hWMD6p3UNjRbr2eJrUpdLjiSVsegxIVDsqLfaLYfAU3qxlqxXtQ7D0HbXlzLlNy6zIaU5bcf-x4cONVHM-rRi1HPI29ty6dhF4cT9JsD3QMSANXUJUMRE2QnIjnNKltaUH7yDLyiQSRy2ibZ1Ke18IUz25RNP6-o5m1zoEjgUYFAveWi0jty7CFnhHUZKMLLGPBq8XC79cD7DawduuZtkIJf0HSlT84eY4jEc9jPRdrbTjdvAa8ql5zD5BI1ZkYbmKepfJuIIykeSqmlMALzPbs1ZQLZqSbBilXWnsOKSzGGxYpA2NpS5kUcTWFz6QbZmjVuYOpj_u-0v7jBM1omu0vL28keKBYPHbXgz-Gvi028jh7z84oCcVJK7qo7ofIobuTd3cmd3dIvEkpAvV67Kr1V6pAfYia8jNDW",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.249437,
#                     "lng": -97.766893
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.25090932989272,
#                         "lng": -97.76570852010728
#                     },
#                     "southwest": {
# ...

# %%
print(places_data["results"][0])
# Out:
# {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 30.249437, 'lng': -97.766893}, 'viewport': {'northeast': {'lat': 30.25090932989272, 'lng': -97.76570852010728}, 'southwest': {'lat': 30.24820967010728, 'lng': -97.76840817989272}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png', 'name': 'Corner Bar', 'opening_hours': {'open_now': False}, 'photos': [{'height': 3648, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100335561761196663504">Corner Bar</a>'], 'photo_reference': 'ATtYBwIB7Oz5mlbriRBSfu_odobbZfqbC85kkLwHaGmrgQUgAKKyOVvjeu9KzbEyUfpGO_2x8j36EMkG9i55iM6dCLy090dSl_JKII1m_lU8ccAs7rgrBSViXeip-steo8klzoP3RsudA420gryhMcZ2liejFRx0xhynwD2f9KH6Of0sOU8J', 'width': 5472}], 'place_id': 'ChIJc8VGEN-0RIYR_47qj-CsoQw', 'plus_code': {'compound_code': '66XM+Q6 Austin, Texas', 'global_code': '862466XM+Q6'}, 'price_level': 1, 'rating': 4.5, 'reference': 'ChIJc8VGEN-0RIYR_47qj-CsoQw', 'scope': 'GOOGLE', 'types': ['bar', 'poin
# ...

# %%
bars = []

for result in places_data["results"]:
    #print(result["business_status"])
    bar_lat = result["geometry"]["location"]["lat"]
    bar_lng = result["geometry"]["location"]["lng"]
    bar_name = result["name"]
    bar_location = result["vicinity"]
    bars.append({"Bar Name": bar_name,
                "Lat": bar_lat,
                 "Lng": bar_lng,
                 "Location": bar_location})                 
    
bars_data = pd.DataFrame(bars)    
bars_data
# Out:
#                              Bar Name        Lat        Lng  \
# 0                          Corner Bar  30.249437 -97.766893
# 1               Revelry Kitchen + Bar  30.263768 -97.727788
# 2                       Workhorse Bar  30.317858 -97.722036
# 3                   Dive Bar & Lounge  30.279892 -97.742087
# 4                       Lavaca St Bar  30.241267 -97.785023
# 5                            Star Bar  30.269952 -97.748538
# 6                  The Roosevelt Room  30.267789 -97.746277
# 7             Corner Restaurant & Bar  30.264570 -97.743832
# 8                   Gibson Street Bar  30.255018 -97.761916
# 9                           HandleBar  30.266620 -97.742054
# 10                           Haymaker  30.284824 -97.717586
# 11            The Garden Grille & Bar  30.222000 -97.688515
# 12               Champions Sports Bar  30.265519 -97.740274
# 13       Cedar Door Patio Bar & Grill  30.264093 -97.742583
# 14                            Key Bar  30.269722 -97.749390
# ...

# %%
# Liquor Stores
# Geo coordinates
target_coordinates = "30.266666, -97.733330"
target_search = "Liquor Stores"
target_radius = 8000
target_type = "retail"

# set up parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response = requests.get(base_url, params=params)

# %%
# print the response url
# print(response.url)

# %%
# convert response to json
stores_data = response.json()

# Print pretty
print(json.dumps(stores_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwLiE7uLVSOlDuvGYbQS6HcAxKpRfXJyBIWnm4HhCOuPq89CTBEzGLDVWn_RWFAV6dHSebjwVtSBSPa5CmiI-d7j5yfrU1VqnzL5vqo4qG1vfyABMjxrPFKfucXXdTYU3vsEr4QR7rvW3LWDYvCtCdJB3JAp2gzQhxzdx1DKefL7nZIb2uMfOM3w25wjCRKZlqJMAnR4wNbP5bt3w6WdZnd5XCED_a7IjvkKGEPhV5BdmVNwDGpuykn1GZh3TXPhjbo41OHJrx80DHnlkGa21ghSRqCfjeIpg8odA3Z_zIR05qGJijxTSvhVjhE1pO-liIvwQ0b3eefwyBy0p3pW96IgJPg7q3Tq3VP0tRIQmnkJpS7LPWmVElHNTEtbyXO2re4EoCRbg_224LVIbYWN_7waOGkRoDp3OUoXE0wYumoiO8c96df6yRjPfpW2cJyxqZZeaQRsLn4",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2001336,
#                     "lng": -97.7863071
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.20140587989273,
#                         "lng": -97.78482397010728
#                     },
# ...

# %%
print(stores_data["results"][0])
# Out:
# {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 30.2001336, 'lng': -97.7863071}, 'viewport': {'northeast': {'lat': 30.20140587989273, 'lng': -97.78482397010728}, 'southwest': {'lat': 30.19870622010728, 'lng': -97.78752362989272}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'name': 'ACE LIQUOR STORE', 'opening_hours': {'open_now': False}, 'photos': [{'height': 1536, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116780138236799593193">Bonny Uwakweh</a>'], 'photo_reference': 'ATtYBwKTbVHEkG4TiqD5VfdvNLTVJn5-1HwuDi7Gq6wtvF-sfZ2qvRmFhVVczEZwXar8maVJvP-nSBydUBpZENN2DGE-wKl7APd9-c7gY7Fd9UPL92JInhy7qdvWSAyBkZLtbmyYVH2W1NHNjkP8lfNB_n0Kz-HHfBSyJyi4sjsiz5r_kMpX', 'width': 2048}], 'place_id': 'ChIJywGSQKtMW4YR89TuBsVxPkw', 'plus_code': {'compound_code': '6627+3F Austin, Texas', 'global_code': '86246627+3F'}, 'rating': 3.7, 'reference': 'ChIJywGSQKtMW4YR89TuBsVxPkw', 'scope': 'GOOGLE', 'types': ['liquor_store'
# ...

# %%
liquor_stores = []

for result in stores_data["results"]:
    #print(result["business_status"])
    ls_lat = result["geometry"]["location"]["lat"]
    ls_lng = result["geometry"]["location"]["lng"]
    ls_name = result["name"]
    ls_location = result["vicinity"]
    liquor_stores.append({"Store Name": ls_name,
                "Lat": ls_lat,
                 "Lng": ls_lng,
                 "Store Location": ls_location})
    
liquor_stores_data = pd.DataFrame(liquor_stores)
liquor_stores_data
# Out:
#                        Store Name        Lat        Lng  \
# 0                ACE LIQUOR STORE  30.200134 -97.786307
# 1           Chris's Liquor Stores  30.247116 -97.773396
# 2   Travis Heights Wine & Spirits  30.238142 -97.739354
# 3             Urban Wine + Liquor  30.264868 -97.744228
# 4          Johnnie's Liquor Store  30.321123 -97.705415
# 5               Warehouse Liquors  30.241312 -97.760465
# 6           Millpond Liquor Store  30.272302 -97.698549
# 7                  Chris's Liquor  30.208205 -97.815198
# 8                    Chris Liquor  30.319972 -97.694647
# 9            Mount Everest Liquor  30.210435 -97.652639
# 10                  C & M Liquors  30.274503 -97.719950
# 11                  Nueces Liquor  30.292154 -97.742950
# 12               New World Liquor  30.257154 -97.746502
# 13         Wiggy's Wine & Spirits  30.276423 -97.751901
# 14     Home Town Liquor & Spirits  30.305800 -97.715347
# 15              A & B Liquors Inc  30.216563 -97.739722
# ...

# %%
#Casinos
# Geo coordinates
target_coordinates = "30.266666, -97.733330"
target_search = "Casino"
target_radius = 8000
target_type = "casino"

# set up parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response = requests.get(base_url, params=params)

# %%
# print the response url
# print(response.url)

# %%
# convert response to json
places_data = response.json()

# Print pretty
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.1948404,
#                     "lng": -97.7773855
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.19622502989272,
#                         "lng": -97.77619667010727
#                     },
#                     "southwest": {
#                         "lat": 30.19352537010727,
#                         "lng": -97.77889632989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "Shuffle 512",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1000,
# ...

# %%
print(places_data["results"][0])
# Out:
# {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 30.1948404, 'lng': -97.7773855}, 'viewport': {'northeast': {'lat': 30.19622502989272, 'lng': -97.77619667010727}, 'southwest': {'lat': 30.19352537010727, 'lng': -97.77889632989272}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'name': 'Shuffle 512', 'opening_hours': {'open_now': False}, 'photos': [{'height': 1000, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116693765600903454387">A Google User</a>'], 'photo_reference': 'ATtYBwIxdxKCUEoZNDDGESoL7i9yoYLvl8jzIiI23cStoMUuv0bLwApBVvXROQsfO4Qkiop2MLEhqWB6xsaZTzVteP3IK6BsR3mlQnjgjaR_JCJgShWETRwDnTRkO2jlLTvRlmTiqVhsu0MT5x97jWG1OqSEVniOroovgsZYKwmXuQwoyr-D', 'width': 1500}], 'place_id': 'ChIJ4fHqYMGzRIYRXsBZ6YH_leU', 'plus_code': {'compound_code': '56VF+W2 Austin, Texas', 'global_code': '862456VF+W2'}, 'rating': 4.4, 'reference': 'ChIJ4fHqYMGzRIYRXsBZ6YH_leU', 'scope': 'GOOGLE', 'types': ['casino', '
# ...

# %%
casinos = []

for result in places_data["results"]:
    #print(result["business_status"])
    casinos_lat = result["geometry"]["location"]["lat"]
    casinos_lng = result["geometry"]["location"]["lng"]
    casinos_name = result["name"]
    casinos_location = result["vicinity"]
    casinos.append({"Casino Name": casinos_name,
                "Lat": casinos_lat,
                 "Lng": casinos_lng,
                 "Location": casinos_location})                 
    
casinos_data = pd.DataFrame(casinos)    
casinos_data
# Out:
#                        Casino Name        Lat        Lng  \
# 0                      Shuffle 512  30.194840 -97.777385
# 1               Three Ring Service  30.247980 -97.776142
# 2    Bovada - Online Casino Austin  30.201493 -97.776375
# 3  Millennium Entertainment Center  30.271908 -97.710887
#
#                                             Location
# 0                 6501 S Congress Ave #1-104, Austin
# 1                         2305 Bluebonnet Ln, Austin
# 2  11013 SHERWOOD GRV, HOUSTON, TX 77043-2866 592...
# 3                           1156 Hargrave St, Austin
